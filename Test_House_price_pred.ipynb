# %%
import pandas as pd
pd.pandas.set_option('display.max_columns',None)
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data=pd.read_csv('test.csv')

# %%
data.head(20
)
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1   1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2   1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3   1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4   1465         120       RL         43.0     5005   Pave   NaN      IR1
# 5   1466          60       RL         75.0    10000   Pave   NaN      IR1
# 6   1467          20       RL          NaN     7980   Pave   NaN      IR1
# 7   1468          60       RL         63.0     8402   Pave   NaN      IR1
# 8   1469          20       RL         85.0    10176   Pave   NaN      Reg
# 9   1470          20       RL         70.0     8400   Pave   NaN      Reg
# 10  1471         120       RH         26.0     5858   Pave   NaN      IR1
# 11  1472         160       RM         21.0     1680   Pave   NaN      Reg
# ...

# %%
#SInce the data set has many features, we can check features which has missing value in %

na_features=[features for features in data.columns if data[features].isnull().sum()>1]

for feature in na_features:
    print(feature, np.round(data[feature].isnull().mean()*100,3),  ' % of missing values')
# Out:
# MSZoning 0.274  % of missing values
# LotFrontage 15.559  % of missing values
# Alley 92.666  % of missing values
# Utilities 0.137  % of missing values
# MasVnrType 1.097  % of missing values
# MasVnrArea 1.028  % of missing values
# BsmtQual 3.016  % of missing values
# BsmtCond 3.084  % of missing values
# BsmtExposure 3.016  % of missing values
# BsmtFinType1 2.879  % of missing values
# BsmtFinType2 2.879  % of missing values
# BsmtFullBath 0.137  % of missing values
# BsmtHalfBath 0.137  % of missing values
# Functional 0.137  % of missing values
# FireplaceQu 50.034  % of missing values
# GarageType 5.209  % of missing values
# GarageYrBlt 5.346  % of missing values
# GarageFinish 5.346  % of missing values
# GarageQual 5.346  % of missing values
# GarageCond 5.346  % of missing values
# PoolQC 99.794  % of missing values
# Fence 80.123  % of missing values
# MiscFeature 96.504  % of missing values

# %%
# we can drop the columns that has more than 50% of missing values
data.drop(data[['Alley','PoolQC','Fence','MiscFeature']],axis=1,inplace=True)

# %%
na_features=[features for features in data.columns if data[features].isnull().sum()>1]

for feature in na_features:
    print(feature, np.round(data[feature].isnull().mean()*100,3),  ' % of missing values')
# Out:
# MSZoning 0.274  % of missing values
# LotFrontage 15.559  % of missing values
# Utilities 0.137  % of missing values
# MasVnrType 1.097  % of missing values
# MasVnrArea 1.028  % of missing values
# BsmtQual 3.016  % of missing values
# BsmtCond 3.084  % of missing values
# BsmtExposure 3.016  % of missing values
# BsmtFinType1 2.879  % of missing values
# BsmtFinType2 2.879  % of missing values
# BsmtFullBath 0.137  % of missing values
# BsmtHalfBath 0.137  % of missing values
# Functional 0.137  % of missing values
# FireplaceQu 50.034  % of missing values
# GarageType 5.209  % of missing values
# GarageYrBlt 5.346  % of missing values
# GarageFinish 5.346  % of missing values
# GarageQual 5.346  % of missing values
# GarageCond 5.346  % of missing values

# %% [markdown]
# ##### From above plots we can indentify there is some relationship with the missing values and the sales price. So we will not remove the null values and impute the null values with any technique.

# %%
## Interpreting numerical variables

# %%
num_features = data._get_numeric_data()

# %%
num_features
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0     1461          20         80.0    11622            5            6
# 1     1462          20         81.0    14267            6            6
# 2     1463          60         74.0    13830            5            5
# 3     1464          60         78.0     9978            6            6
# 4     1465         120         43.0     5005            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1454  2915         160         21.0     1936            4            7
# 1455  2916         160         21.0     1894            4            5
# 1456  2917          20        160.0    20000            5            7
# 1457  2918          85         62.0    10441            5            5
# 1458  2919          60         74.0     9627            7            5
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# ...

# %% [markdown]
# ##### as we can see these varables are datetime: YearBuilt, YearRemodAdd, GarageYrBlt, YrSold

# %%
feature_yrs = data[['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']]

# %%
feature_yrs
# Out:
#       YearBuilt  YearRemodAdd  GarageYrBlt  YrSold
# 0          1961          1961       1961.0    2010
# 1          1958          1958       1958.0    2010
# 2          1997          1998       1997.0    2010
# 3          1998          1998       1998.0    2010
# 4          1992          1992       1992.0    2010
# ...         ...           ...          ...     ...
# 1454       1970          1970          NaN    2006
# 1455       1970          1970       1970.0    2006
# 1456       1960          1996       1960.0    2006
# 1457       1992          1992          NaN    2006
# 1458       1993          1994       1993.0    2006
#
# [1459 rows x 4 columns]

# %%
#analysing features in yrs with our dependent variable

# %%
year_feature = [feature for feature in num_features if 'Yr' in feature or 'Year' in feature]
year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
dis_feature=[feature for feature in num_features if len(data[feature].unique())<25 and feature not in year_feature]
print("Discrete Variables Count: {}".format(len(dis_feature)))
# Out:
# Discrete Variables Count: 16

# %%
dis_feature
# Out:
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MoSold']

# %%
data[dis_feature].tail(10)
# Out:
#       MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  \
# 1449         180            4            6             0           1.0
# 1450         160            4            4             0           0.0
# 1451          20            5            5             0           1.0
# 1452         160            4            5             0           0.0
# 1453         160            4            5             0           0.0
# 1454         160            4            7             0           0.0
# 1455         160            4            5             0           0.0
# 1456          20            5            7             0           1.0
# 1457          85            5            5             0           0.0
# 1458          60            7            5             0           0.0
#
#       BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 1449           0.0         1         0             1             1
# ...

# %%
#Now finding relationship between them with Price

# %%
# Lets interpret Continuous Variable by creating histograms.

cont_features = [feature for feature in num_features if feature not in dis_feature+year_feature+['Id']]
print("Continous Variables Count: {}".format(len(cont_features)))
# Out:
# Continous Variables Count: 16

# %%
cont_features
# Out:
# ['LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'MiscVal']

# %%
for feature in cont_features:
    data=data.copy()
    data[feature].hist(bins=30)
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.title(feature)
    plt.show()

# %%
# As we can see the distributions are skewed, this might be beacuse of outliers and null values. Lets use log transformation

# %%
# %matplotlib inline
import sklearn

# %% [markdown]
# ### Missing Value Treatment

# %%
#categorical missing values

# %%
nan_feature = [feature for feature in data.columns if data[feature].isnull().sum()>1 and data[feature].dtypes == 'O']

# %%
nan_feature
# Out:
# ['MSZoning',
#  'Utilities',
#  'MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond']

# %%
for feature in nan_feature:
    print(feature," missing values: ",np.round(data[feature].isnull().mean()*100,2),"%")
# Out:
# MSZoning  missing values:  0.27 %
# Utilities  missing values:  0.14 %
# MasVnrType  missing values:  1.1 %
# BsmtQual  missing values:  3.02 %
# BsmtCond  missing values:  3.08 %
# BsmtExposure  missing values:  3.02 %
# BsmtFinType1  missing values:  2.88 %
# BsmtFinType2  missing values:  2.88 %
# Functional  missing values:  0.14 %
# FireplaceQu  missing values:  50.03 %
# GarageType  missing values:  5.21 %
# GarageFinish  missing values:  5.35 %
# GarageQual  missing values:  5.35 %
# GarageCond  missing values:  5.35 %

# %%
sns.heatmap(data.isnull(),yticklabels=False, cbar=False)
# Out:
# <AxesSubplot:>

# %%
data['LotFrontage']=data['LotFrontage'].fillna(data['LotFrontage'].mean())

# %%
data['MSZoning'].value_counts()

# %%
data['MSZoning']=data['MSZoning'].fillna(data['MSZoning'].mode()[0])

# %%
data.shape
# Out:
# (1459, 76)

# %%
data['Utilities'].describe()
# Out:
# count       1457
# unique         1
# top       AllPub
# freq        1457
# Name: Utilities, dtype: object

# %%
data['Utilities']=data['Utilities'].fillna(data['Utilities'].mode()[0])

# %%
data.head(2)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0  1461          20       RH         80.0    11622   Pave      Reg
# 1  1462          20       RL         81.0    14267   Pave      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     1Story            5            6       1961
# 1       Norm     1Fam     1Story            6            6       1958
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          1961     Gable  CompShg     VinylSd     VinylSd       None
# 1          1958       Hip  CompShg     Wd Sdng     Wd Sdng    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# ...

# %%
data['MasVnrType'].value_counts()
# Out:
# None       878
# BrkFace    434
# Stone      121
# BrkCmn      10
# Name: MasVnrType, dtype: int64

# %%
data['MasVnrType']=data['MasVnrType'].fillna(data['MasVnrType'].mode()[0])

# %%
data['MasVnrType'].isnull().sum()
# Out:
# 0

# %%
data['MasVnrArea']=data['MasVnrArea'].fillna(data['MasVnrArea'].mode()[0])

# %%
data['BsmtQual']=data['BsmtQual'].fillnana(data['BsmtQual'].mode()[0])

# %%
data['BsmtCond']=data['BsmtCond'].fillna(data['BsmtCond'].mode()[0])

# %%
data['BsmtExposure']=data['BsmtExposure'].fillna(data['BsmtExposure'].mode()[0])

# %%
data['BsmtFinType1']=data['BsmtFinType1'].fillna(data['BsmtFinType1'].mode()[0])

# %%
data['BsmtFinType2']=data['BsmtFinType2'].fillna(data['BsmtFinType2'].mode()[0])

# %%
data['FireplaceQu']=data['FireplaceQu'].fillna(data['FireplaceQu'].mode()[0])

# %%
data['BsmtFullBath'].value_counts()
# Out:
# 0.0    849
# 1.0    584
# 2.0     23
# 3.0      1
# Name: BsmtFullBath, dtype: int64

# %%
data['BsmtFullBath']=data['BsmtFullBath'].fillna(data['BsmtFullBath'].mode()[0])

# %%
data['BsmtHalfBath']=data['BsmtHalfBath'].fillna(data['BsmtHalfBath'].mode()[0])

# %%
data['Functional'].value_counts()
# Out:
# Typ     1357
# Min2      36
# Min1      34
# Mod       20
# Maj1       5
# Maj2       4
# Sev        1
# Name: Functional, dtype: int64

# %%
data['Functional'].head(10)
# Out:
# 0    Typ
# 1    Typ
# 2    Typ
# 3    Typ
# 4    Typ
# 5    Typ
# 6    Typ
# 7    Typ
# 8    Typ
# 9    Typ
# Name: Functional, dtype: object

# %%
data['Functional']=data['Functional'].fillna(data['Functional'].mode()[0])

# %%
data['FireplaceQu']=data['FireplaceQu'].fillna(data['FireplaceQu'].mode()[0])

# %%
data['GarageType']=data['GarageType'].fillna(data['GarageType'].mode()[0])

# %%
data['GarageYrBlt']=data['GarageYrBlt'].fillna(data['GarageYrBlt'].mode()[0])

# %%
data['GarageFinish']=data['GarageFinish'].fillna(data['GarageFinish'].mode()[0])

# %%
data['GarageQual']=data['GarageQual'].fillna(data['GarageQual'].mode()[0])

# %%
data['GarageCond']=data['GarageCond'].fillna(data['GarageCond'].mode()[0])

# %%
pd.pandas.set_option('display.max_rows',None)
pd.DataFrame(data.isnull().sum())
# Out:
#                0
# Id             0
# MSSubClass     0
# MSZoning       0
# LotFrontage    0
# LotArea        0
# Street         0
# LotShape       0
# LandContour    0
# Utilities      0
# LotConfig      0
# LandSlope      0
# Neighborhood   0
# Condition1     0
# Condition2     0
# BldgType       0
# HouseStyle     0
# OverallQual    0
# OverallCond    0
# YearBuilt      0
# YearRemodAdd   0
# RoofStyle      0
# RoofMatl       0
# Exterior1st    1
# Exterior2nd    1
# MasVnrType     0
# MasVnrArea     0
# ExterQual      0
# ExterCond      0
# Foundation     0
# BsmtQual       0
# BsmtCond       0
# BsmtExposure   0
# BsmtFinType1   0
# BsmtFinSF1     1
# BsmtFinType2   0
# BsmtFinSF2     1
# BsmtUnfSF      1
# TotalBsmtSF    1
# Heating        0
# HeatingQC      0
# CentralAir     0
# Electrical     0
# 1stFlrSF       0
# 2ndFlrSF       0
# LowQualFinSF   0
# GrLivArea      0
# BsmtFullBath   0
# BsmtHalfBath   0
# FullBath       0
# HalfBath       0
# BedroomAbvGr   0
# ...

# %%
data['Exterior1st']=data['Exterior1st'].fillna(data['Exterior1st'].mode()[0])

# %%
data['Exterior2nd']=data['Exterior2nd'].fillna(data['Exterior2nd'].mode()[0])

# %%
data['BsmtFinSF1']=data['BsmtFinSF1'].fillna(data['BsmtFinSF1'].mode()[0])

# %%
data['BsmtFinSF2']=data['BsmtFinSF2'].fillna(data['BsmtFinSF2'].mode()[0])

# %%
data['BsmtUnfSF'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data['BsmtUnfSF']=data['BsmtUnfSF'].fillna(data['BsmtUnfSF'].mode()[0])

# %%
data['TotalBsmtSF'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data['TotalBsmtSF']=data['TotalBsmtSF'].fillna(data['TotalBsmtSF'].mode()[0])

# %%
data['KitchenQual'].describe()
# Out:
# count     1458
# unique       4
# top         TA
# freq       757
# Name: KitchenQual, dtype: object

# %%
data['KitchenQual']=data['KitchenQual'].fillna(data['KitchenQual'].mode()[0])

# %%
data['GarageCars']=data['GarageCars'].fillna(data['GarageCars'].mode()[0])

# %%
data['GarageArea']=data['GarageArea'].fillna(data['GarageArea'].median())

# %%
data['SaleType'].describe()
# Out:
# count     1458
# unique       9
# top         WD
# freq      1258
# Name: SaleType, dtype: object

# %%
data['SaleType']=data['SaleType'].fillna(data['SaleType'].mode()[0])

# %%
pd.pandas.set_option('display.max_rows',None)
pd.DataFrame(data.isnull().sum())
# Out:
#                0
# Id             0
# MSSubClass     0
# MSZoning       0
# LotFrontage    0
# LotArea        0
# Street         0
# LotShape       0
# LandContour    0
# Utilities      0
# LotConfig      0
# LandSlope      0
# Neighborhood   0
# Condition1     0
# Condition2     0
# BldgType       0
# HouseStyle     0
# OverallQual    0
# OverallCond    0
# YearBuilt      0
# YearRemodAdd   0
# RoofStyle      0
# RoofMatl       0
# Exterior1st    0
# Exterior2nd    0
# MasVnrType     0
# MasVnrArea     0
# ExterQual      0
# ExterCond      0
# Foundation     0
# BsmtQual       0
# BsmtCond       0
# BsmtExposure   0
# BsmtFinType1   0
# BsmtFinSF1     0
# BsmtFinType2   0
# BsmtFinSF2     0
# BsmtUnfSF      0
# TotalBsmtSF    0
# Heating        0
# HeatingQC      0
# CentralAir     0
# Electrical     0
# 1stFlrSF       0
# 2ndFlrSF       0
# LowQualFinSF   0
# GrLivArea      0
# BsmtFullBath   0
# BsmtHalfBath   0
# FullBath       0
# HalfBath       0
# BedroomAbvGr   0
# ...

# %%
data.to_csv('formulatedtest.csv',index=False)
